# %%
import random
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import numpy as np
import math

# %%
random.random()
# Out:
# 0.5144003752642454

# %%
print(random.uniform(1.0,10.0))
# Out:
# 1.3015535862381866

# %%
x = [random.uniform(0.0,2.0) for _ in range(10)]
y = [random.uniform(0.0,2.0) for _ in range(10)]

# %%
def draw_scatter(x_data, y_data):
    linspace = np.linspace(1, 10, 10)
    plt.figure(figsize=(6, 6))
    plt.xlabel("X(km) * $\mathregular{10^3}$")
    plt.ylabel("Y(km) * $\mathregular{10^3}$")
    plt.scatter(x_data, y_data, label='UT', color='b')
    plt.xticks(linspace)
    plt.yticks(linspace)
    
    plt.legend()

# %%
draw_scatter(x, y)

# %%
# import math
# def random_move(x_data, y_data, speed=1):
#     delta_x = [random.random() for _ in range(len(x_data))]
#     delta_y = [math.sqrt(speed-math.pow(_, 2)) for _ in delta_x]
#     moved_x = [x_data[i] + delta_x[i] for i in range(len(x_data))]
#     moved_y = [y_data[i] + delta_y[i] for i in range(len(x_data))]
#     return moved_x, moved_y

# %%
x
# Out:
# [0.7277631148240451,
#  1.241615353222764,
#  0.6761255551465459,
#  1.482398101988838,
#  1.0742129413771007,
#  0.9642258147894602,
#  0.10709590581222561,
#  0.2832841161443047,
#  1.6530752861926334,
#  0.64589455631778]

# %%
random_move(x, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26352/2709260699.py in <module>
# ----> 1 random_move(x, y)
#
# NameError: name 'random_move' is not defined

# %%
# # 圓的引數方程
# import numpy as np
# import matplotlib.pyplot as plt

# x = np.linspace(-0.5, 0.5, 50)
# y = np.linspace(-0.5, 0.5, 0)

# a, b = np.meshgrid(x, y)

# C = a**2+b**2-0.2

# figure, axes = plt.subplots()

# axes.contour(a,b,C,[0])
# axes.set_aspect(1)

# plt.show()

# %%
# 圓方程的中心半徑形式
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2*np.pi, 100)

radius = 0.5735 # 10**3 km 

a = radius*np.cos(theta)
b = radius*np.sin(theta)

plt.figure(figsize=(10, 10))
figure, ax = plt.subplots(1)

ax.plot(a+1, b+1)
ax.set_aspect(1)
ax.scatter(x, y)
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))

plt.title('Circle using Parametric Equation')
plt.show()

# %%
linspace = np.linspace(0, 2, 3)
plt.figure(figsize=(20, 20))
plt.xlabel("X(km) * $\mathregular{10^3}$")
plt.ylabel("Y(km) * $\mathregular{10^3}$")
plt.scatter(x, y, label='UT', color='b')
# plt.plot(a,b)

circle1 = plt.Circle((50,50), 5.5, color='k', fill=False, linewidth=3)
plt.gca().add_patch(circle1)

for i in range(7):
    for _ in range(6):
        circle1 = plt.Circle((-0.601*3+0.601*i+(0.601*_*1.9), (0.798*_*1.9)), 0.5735, color='k', fill=False, linewidth=3)
        plt.gca().add_patch(circle1)
#         print((0.601*i+(0.601*_*1.9), (0.798*_*1.9)))
#     break
# for i in range(1, int(5/0.601)):
#     for _ in range(4):
#         circle1 = plt.Circle((-0.601*i+(0.601*_*1.9),(0.798*_*1.9)), 0.5735, color='k', fill=False, linewidth=3)
#         plt.gca().add_patch(circle1)
        
# for i in range(int(5/0.601)):
#     for _ in range(4):
#         circle1 = plt.Circle((0.601*i+(0.601*_*1.9), 5-(0.798*_*1.9)), 0.5735, color='k', fill=False, linewidth=3)
#         plt.gca().add_patch(circle1)
# for i in range(1, int(5/0.601)):
#     for _ in range(4):
#         circle1 = plt.Circle((-0.601*i+(0.601*_*1.9),5-(0.798*_*1.9)), 0.5735, color='k', fill=False, linewidth=3)
#         plt.gca().add_patch(circle1)  
        

# satellite_number = int(5/0.601)
for i in range(7):
    plt.plot([-0.601*3+0.601*i, -0.601*3+0.601*(5/0.601)+0.601*i], [0, 0.798*(5/0.601)], color='g')

# for i in range(1, int(5/0.601)):
#     plt.plot([-0.601*i, 0.601*(5/0.601)-0.601*i], [0, 0.798*(5/0.601)], color='g')
    
# for i in range(int(5/0.601)):
#     plt.plot([0.601*i, 0.601*(5/0.601)+0.601*i], [5, 5-0.798*(5/0.601)], color='r')
    
# for i in range(1, int(5/0.601)):
#     plt.plot([-0.601*i, 0.601*(5/0.601)-0.601*i], [5, 5-0.798*(5/0.601)], color='r')
# for i in range(10):
#     circle1 = plt.Circle((0.601*i*1.9, 0.601*i*1.9), 0.5735, color='k', fill=False, linewidth=3)
#     plt.gca().add_patch(circle1)
# for i in range(int(5/0.601)):    
#     plt.plot([0.601*i, 0.601*(5/0.601)+0.601*i], [0, 0.601*(5/0.601)], color='g')
# plt.plot([0.601, 0.601*(5/0.601)+0.601], [0, 0.798*(5/0.601)], color='g')

plt.xlim(-10,10)
plt.ylim(-10,10)

plt.xticks(linspace)
plt.yticks(linspace)
    
# plt.legend()
# Out:
# ([<matplotlib.axis.YTick at 0x206aa617d30>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
linspace = np.linspace(0, 2, 3)
plt.figure(figsize=(20, 20))
plt.xlabel("X(km) * $\mathregular{10^3}$")
plt.ylabel("Y(km) * $\mathregular{10^3}$")
plt.scatter(x, y, label='UT', color='b')
# plt.plot(a,b)

circle1 = plt.Circle((50,50), 5.5, color='k', fill=False, linewidth=3)
plt.gca().add_patch(circle1)

# for i in range(7): # 7個軌道
#     plt.plot([-0.601*3+0.601*i, -0.601*3+0.601*(5/0.601)+0.601*i], [0, 0.798*(5/0.601)], color='g')
#     for _ in range(6): # 每個軌道上有 6顆衛星
#         circle1 = plt.Circle((-0.601*3+0.601*i+(0.601*_*1.9), (0.798*_*1.9)), 0.5735, color='k', fill=False, linewidth=3)
#         plt.gca().add_patch(circle1) 

sin37 = math.sin(math.pi/180*37) # 0.601
sin53 = math.sin(math.pi/180*53) # 0.798
SatellitePerOrbit = 6
SatelliteSpace = 1.9

for i in range(7):
    plt.plot([-SatelliteSpace/2*sin37-sin37*i, SatelliteSpace/2*sin37-sin37*i+sin37*((SatellitePerOrbit-1)*1.9)], [SatelliteSpace/2*sin53+5, -SatelliteSpace/2*sin53+5-sin53*((SatellitePerOrbit-1)*SatelliteSpace)], color='r')
    if i%2==0:
        for _ in range(SatellitePerOrbit):
#             plt.scatter(-sin37*i+(sin37*_*SatelliteSpace), 5-(sin53*_*SatelliteSpace), color='k')
            circle1 = plt.Circle((-sin37*i+(sin37*_*SatelliteSpace), (5-(sin53*_*SatelliteSpace))), 0.5735, color='k', fill=False, linewidth=3)
            plt.gca().add_patch(circle1)
    else:
        for _ in range(SatellitePerOrbit):
#             plt.scatter((SatelliteSpace/2*sin37-sin37*i+(sin37*_*SatelliteSpace)), (5-(sin53*_*SatelliteSpace)-SatelliteSpace/2*sin53), color='k')
            circle1 = plt.Circle((SatelliteSpace/2*sin37-sin37*i+(sin37*_*SatelliteSpace), (5-(sin53*_*SatelliteSpace)-SatelliteSpace/2*sin53)), 0.5735, color='k', fill=False, linewidth=3)
            plt.gca().add_patch(circle1)
# #     break
    
for i in range(7):
    plt.plot([2+sin37*i+SatelliteSpace/2*sin37, 2+sin37*i-sin37*((SatellitePerOrbit-1)*1.9)-SatelliteSpace/2*sin37], [5+SatelliteSpace/2*sin53, 5-sin53*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin53], color='g')
#     plt.plot([0-0.601*i, 0+0.601*(5/0.601)-0.601*i], [-2, 0.798*(5/0.601)-2], color='g')
    if i%2==1:
#         continue
        for _ in range(SatellitePerOrbit):
            circle1 = plt.Circle((2+sin37*i-(sin37*_*SatelliteSpace), (5-(sin53*_*SatelliteSpace))), 0.5735, color='k', fill=False, linewidth=3)
            plt.gca().add_patch(circle1)
    else:
        for _ in range(SatellitePerOrbit):
            circle1 = plt.Circle((2+sin37*i-(sin37*_*SatelliteSpace)-SatelliteSpace/2*sin37, (5-(sin53*_*SatelliteSpace)-SatelliteSpace/2*sin53)), 0.5735, color='k', fill=False, linewidth=3)
            plt.gca().add_patch(circle1)
# #     break

plt.xlim(-10,10)
plt.ylim(-10,10)

plt.xticks(linspace)
plt.yticks(linspace)
# Out:
# ([<matplotlib.axis.YTick at 0x206ab415be0>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
# Circle_Centers=[]
# for i in range(7):
#     if i%2==0:
#         for _ in range(SatellitePerOrbit):
#             Center = (-sin37*i+(sin37*_*SatelliteSpace)), (5-(sin53*_*SatelliteSpace))
#             Circle_Centers.append(Center)
#     else:
#         for _ in range(SatellitePerOrbit):
#             Center = ((SatelliteSpace/2*sin37-sin37*i+(sin37*_*SatelliteSpace)), (5-(sin53*_*SatelliteSpace)-SatelliteSpace/2*sin53))
#             Circle_Centers.append(Center)
# # Circle_Centers

# %%
Circle_Centers

# %%
linspace = np.linspace(0, 2, 3)
plt.cla()
plt.clf()
plt.figure(figsize=(20, 20))
# plt.style.use('classic')
plt.xlabel("X(km) * $\mathregular{10^3}$")
plt.ylabel("Y(km) * $\mathregular{10^3}$")
# plt.scatter(x, y, label='UT', color='b')

for i in range(7):
    plt.plot([-SatelliteSpace/2*sin37-sin37*i, SatelliteSpace/2*sin37-sin37*i+sin37*((SatellitePerOrbit-1)*SatelliteSpace)], [SatelliteSpace/2*sin53+5, -SatelliteSpace/2*sin53+5-sin53*((SatellitePerOrbit-1)*SatelliteSpace)], color='r')
    plt.plot([2+sin37*i+SatelliteSpace/2*sin37, 2+sin37*i-sin37*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin37], [5+SatelliteSpace/2*sin53, 5-sin53*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin53], color='g')
    print([-SatelliteSpace/2*sin37-sin37*i, SatelliteSpace/2*sin37-sin37*i+sin37*((SatellitePerOrbit-1)*SatelliteSpace)], [SatelliteSpace/2*sin53+5, -SatelliteSpace/2*sin53+5-sin53*((SatellitePerOrbit-1)*SatelliteSpace)])
    print([2+sin37*i+SatelliteSpace/2*sin37, 2+sin37*i-sin37*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin37], [5+SatelliteSpace/2*sin53, 5-sin53*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin53])

sin37 = math.sin(math.pi/180*37) # 0.601
sin53 = math.sin(math.pi/180*53) # 0.798
SatellitePerOrbit = 6
SatelliteSpace = 1.976
OrbitLength = SatelliteSpace * SatellitePerOrbit
SatelliteVelocity = 7.61268 * math.pow(10, -3) # 10**3 km/s
PeriodOrbit = int(OrbitLength / SatelliteVelocity) # 1557s 繞一圈
NumberOfOrbit = 7


# ---------------------------------得到衛星的圓心---------------------------------
Red_Circle_Centers=[]
for i in range(NumberOfOrbit):
    if i%2==0:
        for _ in range(SatellitePerOrbit):
            Center = [-sin37*i+(sin37*_*SatelliteSpace), 5-(sin53*_*SatelliteSpace)]
            Red_Circle_Centers.append(Center)
    else:
        for _ in range(SatellitePerOrbit):
            Center = [SatelliteSpace/2*sin37-sin37*i+(sin37*_*SatelliteSpace), 5-(sin53*_*SatelliteSpace)-SatelliteSpace/2*sin53]
            Red_Circle_Centers.append(Center)
    break

# -------------------------根據圓心畫出衛星的中心和覆蓋範圍-------------------------

for i in range(len(Red_Circle_Centers)):
    plt.scatter(Red_Circle_Centers[i][0] , Red_Circle_Centers[i][1], color='k')
    circle1 = plt.Circle(Red_Circle_Centers[i], 0.5735, color='k', fill=False, linewidth=3)
    plt.gca().add_patch(circle1)
# ---------------------------------得到衛星的圓心---------------------------------
# Greed_Circle_Centers=[]
# for i in range(NumberOfOrbit):
#     if i%2==1:
#         for _ in range(SatellitePerOrbit):
#             Center = ((2+sin37*i-(sin37*_*SatelliteSpace), (5-(sin53*_*SatelliteSpace))))
#             Greed_Circle_Centers.append(Center)
#     else:
#         for _ in range(SatellitePerOrbit):
#             Center = ((2+sin37*i-(sin37*_*SatelliteSpace)-SatelliteSpace/2*sin37, (5-(sin53*_*SatelliteSpace)-SatelliteSpace/2*sin53)))
#             Greed_Circle_Centers.append(Center)
# # -------------------------根據圓心畫出衛星的中心和覆蓋範圍-------------------------
# for i in range(len(Greed_Circle_Centers)):
#     plt.scatter(Greed_Circle_Centers[i][0] , Greed_Circle_Centers[i][1], color='k')
#     circle1 = plt.Circle(Greed_Circle_Centers[i], 0.5735, color='k', fill=False, linewidth=3)
#     plt.gca().add_patch(circle1)


plt.xlim(-10,10)
plt.ylim(-10,10)

plt.xticks(linspace)
plt.yticks(linspace)
# Out:
# [-0.5717242719944459, 6.288966991938905] [5.758703734544929, -3.3457410799942107]
# [2.5717242719944458, -4.288966991938905] [5.758703734544929, -3.34574107999421]
# [-1.1735392951464942, 5.687151968786856] [5.758703734544929, -3.3457410799942107]
# [3.1735392951464942, -3.6871519687868557] [5.758703734544929, -3.34574107999421]
# [-1.7753543182985423, 5.085336945634808] [5.758703734544929, -3.3457410799942107]
# [3.7753543182985423, -3.0853369456348076] [5.758703734544929, -3.34574107999421]
# [-2.377169341450591, 4.48352192248276] [5.758703734544929, -3.3457410799942107]
# [4.377169341450591, -2.4835219224827596] [5.758703734544929, -3.34574107999421]
# [-2.978984364602639, 3.881706899330711] [5.758703734544929, -3.3457410799942107]
# [4.978984364602639, -1.8817068993307111] [5.758703734544929, -3.34574107999421]
# [-3.5807993877546873, 3.2798918761786626] [5.758703734544929, -3.3457410799942107]
# [5.580799387754688, -1.2798918761786626] [5.758703734544929, -3.34574107999421]
# ...

# %%
len(Red_Circle_Centers[0])

# %%
int(OrbitLength / SatelliteVelocity)*10**3

# %%
# # *********************** 毫秒 為單位 ***********************
# RedLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)*10**3])
# GreenLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)*10**3])
# for i in range(NumberOfOrbit):
#     RedLine_x[i] = np.linspace(-SatelliteSpace/2*sin37-sin37*i, SatelliteSpace/2*sin37-sin37*i+sin37*((SatellitePerOrbit-1)*SatelliteSpace), int(OrbitLength / SatelliteVelocity)*10**3)
#     GreenLine_x[i] = np.linspace(2+sin37*i+SatelliteSpace/2*sin37, 2+sin37*i-sin37*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin37, int(OrbitLength / SatelliteVelocity)*10**3)
    
# Index_RedLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
# Index_GreenLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
# for i in range(NumberOfOrbit):
#     if i % 2 == 1:
#         Index_RedLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6 *10**3), SatellitePerOrbit).astype(int)
#         Index_GreenLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6*10**3), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2*10**3)
#     else:
#         Index_RedLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6*10**3), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2*10**3)
#         Index_GreenLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6*10**3), SatellitePerOrbit).astype(int)
        
# y_start = 5.789051883926725
# y_end = -3.6795707231939776
# y_table = np.linspace(y_start, y_end, int(OrbitLength / SatelliteVelocity)*10**3)

# %%
# *********************** 秒 為單位 ***********************
RedLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
GreenLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
BlueLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
GlodLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])

for i in range(NumberOfOrbit):
    RedLine_x[i] = np.linspace(-SatelliteSpace/2*sin37-sin37*i, SatelliteSpace/2*sin37-sin37*i+sin37*((SatellitePerOrbit-1)*SatelliteSpace), int(OrbitLength / SatelliteVelocity))
    GreenLine_x[i] = np.linspace(2+sin37*i+SatelliteSpace/2*sin37, 2+sin37*i-sin37*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin37, int(OrbitLength / SatelliteVelocity))
    BlueLine_x[i] = np.linspace(0.3-SatelliteSpace/2*sin378-sin378*i, 0.3+SatelliteSpace/2*sin378-sin378*i+sin378*((SatellitePerOrbit-1)*SatelliteSpace), int(OrbitLength / SatelliteVelocity))
    GlodLine_x[i] = np.linspace(2.3+sin378*i+SatelliteSpace/2*sin378, 2.3+sin378*i-sin378*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin378, int(OrbitLength / SatelliteVelocity))
    
Index_RedLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
Index_GreenLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
Index_BlueLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
Index_GlodLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
for i in range(NumberOfOrbit):
    if i % 2 == 1:
        Index_RedLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6 ), SatellitePerOrbit).astype(int)
        Index_GreenLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)
        Index_BlueLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int)
        Index_GlodLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int)
    else:
        Index_RedLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)
        Index_GreenLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int)
        Index_BlueLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)
        Index_GlodLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)

Index_BlueLocation += int(OrbitLength / SatelliteVelocity / 6 / 4)
Index_GlodLocation += int(OrbitLength / SatelliteVelocity / 6 / 4)

y_start = 5.789051883926725
y_end = -3.6795707231939776
y_table = np.linspace(y_start, y_end, int(OrbitLength / SatelliteVelocity))
# *********************** 秒 為單位 ***********************

# %%
Index_GlodLocation

# %%
Index_GlodLocation

# %%
def random_user(number):
    x = [random.uniform(0.0,2.0) for _ in range(number)]
    y = [random.uniform(0.0,2.0) for _ in range(number)]
    plt.scatter(x, y, label='UT', color='b')

# %%
test = np.zeros([NumberOfOrbit*SatellitePerOrbit*4, 2])
test[1] = GlodCenter_x, GlodCenter_y
print(test)
del test

# %%
for i in range(NumberOfOrbit): # 7
    for s in range(SatellitePerOrbit): # 6
        print(i*24 +  s*4)
        print(i*24 +  s*4 + 1)
        print(i*24 +  s*4 + 2)
        print(i*24 +  s*4 + 3)

# %%
Index_GreenLocation

# %%
del draw_orbits

# %%
import copy

linspace = np.linspace(0, 2, 3)
plt.figure(figsize=(20, 20))
# plt.style.use('classic')
plt.xlabel("X(km) * $\mathregular{10^3}$")
plt.ylabel("Y(km) * $\mathregular{10^3}$")

# random_user(100)

sin37 = math.sin(math.pi/180*37) # 0.601
sin53 = math.sin(math.pi/180*53) # 0.798
sin378 = math.sin(math.pi/180*37.8)
sin532 = math.sin(math.pi/180*53.2)
SatellitePerOrbit = 6
SatelliteSpace = 1.976 # 衛星之間的距離
OrbitLength = SatelliteSpace * SatellitePerOrbit
SatelliteVelocity = 7.61268 * math.pow(10, -3) # 10**3 km/s
PeriodOrbit = int(OrbitLength / SatelliteVelocity) # 1557s 繞一圈
NumberOfOrbit = 7

# *********************** 秒 為單位 ***********************
RedLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
GreenLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
BlueLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
GlodLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])

for i in range(NumberOfOrbit):
    RedLine_x[i] = np.linspace(-SatelliteSpace/2*sin37-sin37*i, SatelliteSpace/2*sin37-sin37*i+sin37*((SatellitePerOrbit-1)*SatelliteSpace), int(OrbitLength / SatelliteVelocity))
    GreenLine_x[i] = np.linspace(2+sin37*i+SatelliteSpace/2*sin37, 2+sin37*i-sin37*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin37, int(OrbitLength / SatelliteVelocity))
    BlueLine_x[i] = np.linspace(0.3-SatelliteSpace/2*sin378-sin378*i, 0.3+SatelliteSpace/2*sin378-sin378*i+sin378*((SatellitePerOrbit-1)*SatelliteSpace), int(OrbitLength / SatelliteVelocity))
    GlodLine_x[i] = np.linspace(2.3+sin378*i+SatelliteSpace/2*sin378, 2.3+sin378*i-sin378*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin378, int(OrbitLength / SatelliteVelocity))
    
Index_RedLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
Index_GreenLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
Index_BlueLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
Index_GlodLocation = np.zeros([NumberOfOrbit, SatellitePerOrbit])
for i in range(NumberOfOrbit):
    if i % 2 == 1:
        Index_RedLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6 ), SatellitePerOrbit).astype(int)
        Index_GreenLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)
        Index_BlueLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int)
        Index_GlodLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int)
    else:
        Index_RedLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)
        Index_GreenLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int)
        Index_BlueLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)
        Index_GlodLocation[i] = np.linspace(0, int(OrbitLength / SatelliteVelocity * 5 / 6), SatellitePerOrbit).astype(int) + int(OrbitLength / SatelliteVelocity / 6 / 2)

Index_BlueLocation += int(OrbitLength / SatelliteVelocity / 6 / 4)
Index_GlodLocation += int(OrbitLength / SatelliteVelocity / 6 / 4)

y_start = 5.789051883926725
y_end = -3.6795707231939776
y_table = np.linspace(y_start, y_end, int(OrbitLength / SatelliteVelocity))
# *********************** 秒 為單位 ***********************


All_Center = np.zeros([NumberOfOrbit*SatellitePerOrbit*4, 2]) # 所有衛星的中心位置

for i in range(NumberOfOrbit):
    plt.plot([RedLine_x[i][0], RedLine_x[i][-1]], [y_table[0], y_table[-1]], color='r')
    plt.plot([GreenLine_x[i][0], GreenLine_x[i][-1]], [y_table[0], y_table[-1]], color='g')
    plt.plot([BlueLine_x[i][0], BlueLine_x[i][-1]], [y_table[0], y_table[-1]], color='deepskyblue')
    plt.plot([GlodLine_x[i][0], GlodLine_x[i][-1]], [y_table[0], y_table[-1]], color='gold')

def Inintial_All_Center(All_Center):
    for i in range(NumberOfOrbit):
        for s in range(SatellitePerOrbit):
            RedCenter_x = RedLine_x[i][int(Index_RedLocation[i][s])]
            RedCenter_y = y_table[int(Index_RedLocation[i][s])]
            plt.scatter(RedCenter_x, RedCenter_y, color='k')
            circle1 = plt.Circle([RedCenter_x, RedCenter_y], 0.5735, color='k', fill=False, linewidth=1)
            plt.gca().add_patch(circle1)
            GreenCenter_x = GreenLine_x[i][int(Index_GreenLocation[i][s])]
            GreenCenter_y = y_table[int(Index_GreenLocation[i][s])]
            plt.scatter(GreenCenter_x, GreenCenter_y, color='k')
            circle1 = plt.Circle([GreenCenter_x, GreenCenter_y], 0.5735, color='k', fill=False, linewidth=1)
            plt.gca().add_patch(circle1)
            BlueCenter_x = BlueLine_x[i][int(Index_BlueLocation[i][s])]
            BlueCenter_y = y_table[int(Index_BlueLocation[i][s])]
            plt.scatter(BlueCenter_x, BlueCenter_y, color='k')
            circle1 = plt.Circle([BlueCenter_x, BlueCenter_y], 0.5735, color='k', fill=False, linewidth=1)
            plt.gca().add_patch(circle1)
            GlodCenter_x = GlodLine_x[i][int(Index_GlodLocation[i][s])]
            GlodCenter_y = y_table[int(Index_GlodLocation[i][s])]
            plt.scatter(GlodCenter_x, GlodCenter_y, color='k')
            circle1 = plt.Circle([GlodCenter_x, GlodCenter_y], 0.5735, color='k', fill=False, linewidth=1)
            plt.gca().add_patch(circle1)
            All_Center[i * 24 + s * 4] = RedCenter_x, RedCenter_y
            All_Center[i * 24 + s * 4 + 1] = GreenCenter_x, GreenCenter_y
            All_Center[i * 24 + s * 4 + 2] = BlueCenter_x, BlueCenter_y
            All_Center[i * 24 + s * 4 + 3] = GlodCenter_x, GlodCenter_y
    return All_Center
    
Inintial_All_Center(All_Center)


# # -------------------------- tracing move --------------
def Satellites_Centers_at_time(Centers, second):
    Temporary_Centers = copy.deepcopy(Centers)
    for i in range(NumberOfOrbit):
        for s in range(SatellitePerOrbit):
            RedCenter_x = RedLine_x[i][(int(Index_RedLocation[i][s])+second)%1557]
            RedCenter_y = y_table[(int(Index_RedLocation[i][s])+second)%1557]
            GreenCenter_x = GreenLine_x[i][(int(Index_GreenLocation[i][s])-second)%1557]
            GreenCenter_y = y_table[(int(Index_GreenLocation[i][s])-second)%1557]
            BlueCenter_x = BlueLine_x[i][(int(Index_BlueLocation[i][s])+second)%1557]
            BlueCenter_y = y_table[(int(Index_BlueLocation[i][s])+second)%1557]
            GlodCenter_x = GlodLine_x[i][(int(Index_GlodLocation[i][s])-second)%1557]
            GlodCenter_y = y_table[(int(Index_GlodLocation[i][s])-second)%1557]
            Temporary_Centers[i * 24 + s * 4] = RedCenter_x, RedCenter_y
            Temporary_Centers[i * 24 + s * 4 + 1] = GreenCenter_x, GreenCenter_y
            Temporary_Centers[i * 24 + s * 4 + 2] = BlueCenter_x, BlueCenter_y
            Temporary_Centers[i * 24 + s * 4 + 3] = GlodCenter_x, GlodCenter_y
            plt.scatter(RedCenter_x, RedCenter_y, color='y')
            plt.scatter(GreenCenter_x, GreenCenter_y, color='y')
            plt.scatter(BlueCenter_x, BlueCenter_y, color='y')
            plt.scatter(GlodCenter_x, GlodCenter_y, color='y')
    return Temporary_Centers

# # -------------------------- tracing move --------------
def TracingMove(second):
    for i in range(NumberOfOrbit):
    #     plt.plot([RedLine_x[i][0], RedLine_x[i][-1]], [y_table[0], y_table[-1]], color='r')
    #     plt.plot([GreenLine_x[i][0], GreenLine_x[i][-1]], [y_table[0], y_table[-1]], color='g')
        for s in range(SatellitePerOrbit):
            RedCenter_x = RedLine_x[i][(int(Index_RedLocation[i][s])+second)%1557]
            RedCenter_y = y_table[(int(Index_RedLocation[i][s])+second)%1557]
            plt.scatter(RedCenter_x, RedCenter_y, color='y')
#             circle1 = plt.Circle([RedCenter_x, RedCenter_y], 0.5735, color='k', fill=False, linewidth=1)
#             plt.gca().add_patch(circle1)

            GreenCenter_x = GreenLine_x[i][(int(Index_GreenLocation[i][s])-second)%1557]
            GreenCenter_y = y_table[(int(Index_GreenLocation[i][s])-second)%1557]
            plt.scatter(GreenCenter_x, GreenCenter_y, color='y')
#             circle1 = plt.Circle([GreenCenter_x, GreenCenter_y], 0.5735, color='k', fill=False, linewidth=1)
#             plt.gca().add_patch(circle1)

            BlueCenter_x = BlueLine_x[i][(int(Index_BlueLocation[i][s])+second)%1557]
            BlueCenter_y = y_table[(int(Index_BlueLocation[i][s])+second)%1557]
            plt.scatter(BlueCenter_x, BlueCenter_y, color='y')
#             circle1 = plt.Circle([GreenCenter_x, GreenCenter_y], 0.5735, color='k', fill=False, linewidth=1)
#             plt.gca().add_patch(circle1)

            GlodCenter_x = GlodLine_x[i][(int(Index_GlodLocation[i][s])-second)%1557]
            GlodCenter_y = y_table[(int(Index_GlodLocation[i][s])-second)%1557]
            plt.scatter(GlodCenter_x, GlodCenter_y, color='y')
#             circle1 = plt.Circle([GreenCenter_x, GreenCenter_y], 0.5735, color='k', fill=False, linewidth=1)
#             plt.gca().add_patch(circle1)
# TracingMove(10)


# Satellites_Centers_at_time(All_Center, 10)

plt.xlim(-10,10)
plt.ylim(-10,10)

plt.xticks(linspace)
plt.yticks(linspace)
# Out:
# ([<matplotlib.axis.YTick at 0x206ad777c50>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
# # *********************** 秒 為單位 ***********************
# BlueLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
# GlodLine_x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
# for i in range(NumberOfOrbit):
#     BlueLine_x[i] = np.linspace(0.3-SatelliteSpace/2*sin378-sin378*i, 0.3+SatelliteSpace/2*sin378-sin378*i+sin378*((SatellitePerOrbit-1)*SatelliteSpace), int(OrbitLength / SatelliteVelocity))
#     GlodLine_x[i] = np.linspace(2.3+sin378*i+SatelliteSpace/2*sin378, 2.3+sin378*i-sin378*((SatellitePerOrbit-1)*SatelliteSpace)-SatelliteSpace/2*sin378, int(OrbitLength / SatelliteVelocity))

# %%
# linspace = np.linspace(0, 2, 3)
# plt.figure(figsize=(20, 20))
# # plt.style.use('classic')
# plt.xlabel("X(km) * $\mathregular{10^3}$")
# plt.ylabel("Y(km) * $\mathregular{10^3}$")

# # random_user(100)

# sin378 = math.sin(math.pi/180*37.8) # 0.601
# sin532 = math.sin(math.pi/180*53.2) # 0.798
# SatellitePerOrbit = 6
# SatelliteSpace = 1.976
# OrbitLength = SatelliteSpace * SatellitePerOrbit
# SatelliteVelocity = 7.61268 * math.pow(10, -3) # 10**3 km/s
# PeriodOrbit = int(OrbitLength / SatelliteVelocity) # 1557s 繞一圈
# NumberOfOrbit = 7

# for i in range(NumberOfOrbit):
#     plt.plot([BlueLine_x[i][0], BlueLine_x[i][-1]], [y_table[0], y_table[-1]], color='deepskyblue')
#     plt.plot([GlodLine_x[i][0], GlodLine_x[i][-1]], [y_table[0], y_table[-1]], color='gold')
#     for s in range(SatellitePerOrbit):
#         BlueCenter_x = BlueLine_x[i][int(Index_BlueLocation[i][s])]
#         BlueCenter_y = y_table[int(Index_BlueLocation[i][s])]
#         plt.scatter(BlueCenter_x, BlueCenter_y, color='k')
#         GlodCenter_x = GlodLine_x[i][int(Index_GlodLocation[i][s])]
#         GlodCenter_y = y_table[int(Index_GlodLocation[i][s])]
#         plt.scatter(GlodCenter_x, GlodCenter_y, color='k')

# # ************************ Moving ************************
# for i in range(NumberOfOrbit):
#     for s in range(SatellitePerOrbit):
#         BlueCenter_x = BlueLine_x[i][(int(Index_BlueLocation[i][s])+100)%1557]
#         BlueCenter_y = y_table[(int(Index_BlueLocation[i][s])+100)%1557]
#         plt.scatter(BlueCenter_x, BlueCenter_y, color='y')
# #             circle1 = plt.Circle([RedCenter_x, RedCenter_y], 0.5735, color='k', fill=False, linewidth=1)
# #             plt.gca().add_patch(circle1)

#         GlodCenter_x = GlodLine_x[i][(int(Index_GlodLocation[i][s])-100)%1557]
#         GlodCenter_y = y_table[(int(Index_GlodLocation[i][s])-100)%1557]
#         plt.scatter(GlodCenter_x, GlodCenter_y, color='y')


# plt.xlim(-10,10)
# plt.ylim(-10,10)

# plt.xticks(linspace)
# plt.yticks(linspace)

# %%
# # *********************************************************** 製作 GIF圖 *********************************************************** 

# import matplotlib.pyplot as plt
# from matplotlib.animation import FuncAnimation
# import numpy as np
# # from matplotlib.animation import PillowWriter

# plt.clf()
# plt.style.use('dark_background')

# n_points = 100
# theta = np.linspace(0, 2 * np.pi, n_points)
# e_radius = 5
# m_radius = 7

# # x = e_radius * np.sin(theta)
# # y = e_radius * np.cos(theta)
# # print(x[0], y[0])
# # print(type(x))


# # x = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
# # y = np.zeros([NumberOfOrbit, int(OrbitLength / SatelliteVelocity)])
# x = np.zeros([NumberOfOrbit, 500])
# y = np.zeros([NumberOfOrbit, 500])

# for orbit in range(NumberOfOrbit):
#         for i in range(500):
#             x[orbit][i] = RedLine_x[orbit][i] + 2
#             y[orbit][i] = y_table[i] - 5.5
            
# # for orbit in range(NumberOfOrbit):
# #     if orbit % 2 == 0:
# # #         x[orbit][i] = x[orbit][i]
# #         for i in range(int(100/6)):
# #             x[orbit, [i, ]] = x[orbit, []]
# #     A[:,[0,2]] = A[:, [2,0]]
            
# # x = np.zeros(100)
# # y = np.zeros(100)        
# # for i in range(100):
# #     x[i] = RedLine_x[0][i] + 2
# #     y[i] = y_table[i] - 5.5
    

# # xx = m_radius * np.sin(theta)
# # yy = m_radius * np.cos(theta)

# fig, ax = plt.subplots(figsize=(10, 10))
# ax = plt.axes(xlim=(-2, 5), ylim=(-5, 2))

# # circle_0=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # ax.add_artist(circle_0)
# circle_1_0=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_1_1=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_1_2=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# circle_1_3=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_1_4=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_1_5=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# ax.add_artist(circle_1_0)
# # ax.add_artist(circle_1_1)
# # ax.add_artist(circle_1_2)
# ax.add_artist(circle_1_3)
# # ax.add_artist(circle_1_4)
# # ax.add_artist(circle_1_5)
# circle_2_0=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_2_1=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_2_2=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# circle_2_3=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_2_4=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_2_5=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# ax.add_artist(circle_2_0)
# # ax.add_artist(circle_2_1)
# # ax.add_artist(circle_2_2)
# ax.add_artist(circle_2_3)
# # ax.add_artist(circle_2_4)
# # ax.add_artist(circle_2_5)
# circle_3_0=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_3_1=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_3_2=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# circle_3_3=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_3_4=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # circle_3_5=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# ax.add_artist(circle_3_0)
# # ax.add_artist(circle_3_1)
# # ax.add_artist(circle_3_2)
# ax.add_artist(circle_3_3)
# # ax.add_artist(circle_3_4)
# # ax.add_artist(circle_3_5)
# # circle_4=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # ax.add_artist(circle_4)
# # circle_5=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # ax.add_artist(circle_5)
# # circle_6=plt.Circle(np.array([0, 0]),0.5735,color='r',fill=False, clip_on = False)
# # ax.add_artist(circle_6)


# # earth_0, = ax.plot([], [], 'g.', markersize=15)
# earth_1_0, = ax.plot([], [], 'g.', markersize=15)
# # earth_1_1, = ax.plot([], [], 'g.', markersize=15)
# # earth_1_2, = ax.plot([], [], 'g.', markersize=15)
# earth_1_3, = ax.plot([], [], 'g.', markersize=15)
# # earth_1_4, = ax.plot([], [], 'g.', markersize=15)
# # earth_1_5, = ax.plot([], [], 'g.', markersize=15)
# earth_2_0, = ax.plot([], [], 'g.', markersize=15)
# # earth_2_1, = ax.plot([], [], 'g.', markersize=15)
# # earth_2_2, = ax.plot([], [], 'g.', markersize=15)
# earth_2_3, = ax.plot([], [], 'g.', markersize=15)
# # earth_2_4, = ax.plot([], [], 'g.', markersize=15)
# # earth_2_5, = ax.plot([], [], 'g.', markersize=15)
# earth_3_0, = ax.plot([], [], 'g.', markersize=15)
# # earth_3_1, = ax.plot([], [], 'g.', markersize=15)
# # earth_3_2, = ax.plot([], [], 'g.', markersize=15)
# earth_3_3, = ax.plot([], [], 'g.', markersize=15)
# # earth_3_4, = ax.plot([], [], 'g.', markersize=15)
# # earth_3_5, = ax.plot([], [], 'g.', markersize=15)
# # earth_4, = ax.plot([], [], 'g.', markersize=15)
# # earth_5, = ax.plot([], [], 'g.', markersize=15)
# # earth_6, = ax.plot([], [], 'g.', markersize=15)
# # mars, = ax.plot([], [], 'r.', markersize=15)
# ax.plot(0, 0, 'X', markersize=5, color="yellow")
# plt.grid(True, lw=0.3)

# for orbit in range(1, 4):
#     ax.plot(x[orbit], y[orbit], 'g-')

# # ax.plot(xx, yy, 'r-')

# def animate(i):
# #     earth, = ax.plot([], [], 'g.', markersize=15)
# #     earth_0.set_data(x[0][i], y[0][i])
#     earth_1_0.set_data(x[1][(i+50)%500], y[1][(i+50)%500])
# #     earth_1_1.set_data(x[1][(i+100)%300], y[1][(i+100)%300])
# #     earth_1_2.set_data(x[1][(i+150)%300], y[1][(i+150)%300])
#     earth_1_3.set_data(x[1][(i+300)%500], y[1][(i+300)%500])
# #     earth_1_4.set_data(x[1][(i+250)%300], y[1][(i+250)%300])
# #     earth_1_5.set_data(x[1][(i)%300], y[1][(i)%300])
#     circle_1_0.set_center([x[1][(i+50)%500], y[1][(i+50)%500]])
# #     circle_1_1.set_center([x[1][(i+100)%300], y[1][(i+100)%300]])
# #     circle_1_2.set_center([x[1][(i+150)%300], y[1][(i+150)%300]])
#     circle_1_3.set_center([x[1][(i+300)%500], y[1][(i+300)%500]])
# #     circle_1_4.set_center([x[1][(i+250)%300], y[1][(i+250)%300]])
# #     circle_1_5.set_center([x[1][(i)%300], y[1][(i)%300]])
#     earth_2_0.set_data(x[2][(i+175)%500], y[2][(i+175)%500])
# #     earth_2_1.set_data(x[2][(i+75)%300], y[2][(i+75)%300])
# #     earth_2_2.set_data(x[2][(i+125)%300], y[2][(i+125)%300])
#     earth_2_3.set_data(x[2][(i+425)%500], y[2][(i+425)%500])
# #     earth_2_4.set_data(x[2][(i+225)%300], y[2][(i+225)%300])
# #     earth_2_5.set_data(x[2][(i+275)%300], y[2][(i+275)%300])
#     circle_2_0.set_center([x[2][(i+175)%500], y[2][(i+175)%500]])
# #     circle_2_1.set_center([x[2][(i+75)%300], y[2][(i+75)%300]])
# #     circle_2_2.set_center([x[2][(i+125)%300], y[2][(i+125)%300]])
#     circle_2_3.set_center([x[2][(i+425)%500], y[2][(i+425)%500]])
# #     circle_2_4.set_center([x[2][(i+225)%300], y[2][(i+225)%300]])
# #     circle_2_5.set_center([x[2][(i+275)%300], y[2][(i+275)%300]])
#     earth_3_0.set_data(x[3][(i+50)%500], y[3][(i+50)%500])
# #     earth_3_1.set_data(x[3][(i+100)%300], y[3][(i+100)%300])
# #     earth_3_2.set_data(x[3][(i+150)%300], y[3][(i+150)%300])
#     earth_3_3.set_data(x[3][(i+300)%500], y[3][(i+300)%500])
# #     earth_3_4.set_data(x[3][(i+250)%300], y[3][(i+250)%300])
# #     earth_3_5.set_data(x[3][(i)%300], y[3][(i)%300])
#     circle_3_0.set_center([x[3][(i+50)%500], y[3][(i+50)%500]])
# #     circle_3_1.set_center([x[3][(i+100)%300], y[3][(i+100)%300]])
# #     circle_3_2.set_center([x[3][(i+150)%300], y[3][(i+150)%300]])
#     circle_3_3.set_center([x[3][(i+300)%500], y[3][(i+300)%500]])
# #     circle_3_4.set_center([x[3][(i+250)%300], y[3][(i+250)%300]])
# #     circle_3_5.set_center([x[3][(i)%300], y[3][(i)%300]])
# #     earth_2.set_data(x[2][i], y[2][i])
# #     earth_3.set_data(x[3][(i+50)%300], y[3][(i+50)%300])
# #     earth_4.set_data(x[4][i], y[4][i])
# #     earth_5.set_data(x[5][(i+20)%100], y[5][(i+20)%100])
# #     earth_6.set_data(x[6][i], y[6][i])
    
# #     circle_0.set_center([x[0][i], y[0][i]])
# #     circle_1.set_center([x[1][(i+50)%300], y[1][(i+50)%300]])
# #     circle_2.set_center([x[2][i], y[2][i]])
# #     circle_3.set_center([x[3][(i+50)%300], y[3][(i+50)%300]])
# #     circle_4.set_center([x[4][i], y[4][i]])
# #     circle_5.set_center([x[5][(i+20)%100], y[5][(i+20)%100]])
# #     circle_6.set_center([x[6][i], y[6][i]])
    
# #     circle_0.set_radius(0.5735)
# #     return earth

# anim = FuncAnimation(fig, animate, frames=300, interval=2, repeat=False)
# anim.save('cirlce_ani.gif', writer='pillow')
# plt.show()

# %%
# testData = np.random.rand(100,2)-[0.5, 0.5]


# # fig, ax = plt.subplots()
# fig, ax = plt.subplots(figsize=(5, 5))
# ax = plt.axes(xlim=(-2, 2), ylim=(-2, 2))


# # i is the radius
# def animate(i):
#     #init()
#     #you don't want to redraw the same dots over and over again, do you?
# #     center = np.array([x[i], y[i]-5])
# #     circle1.set_center(center)
#     circle1=plt.Circle(np.array([0, 0]),0,color='r',fill=False, clip_on = False)
#     ax.add_artist(circle1)
#     circle1.set_radius(i)


# def init():
#     sctPlot, = ax.plot(testData[:,0], testData[:,1], ".")
#     return sctPlot,

# ani = FuncAnimation(fig, animate, np.arange(0, 10, 1), init_func=init,
#     interval=250, blit=False)
# ani.save('cirlce.gif', writer='pillow')
# plt.show()

# %%
All_Center # 所有衛星的中心位置
# Out:
# array([[-3.05703467e-03,  5.00405682e+00],
#        [ 2.59459324e+00,  5.78905188e+00],
#        [ 5.95770982e-01,  4.61460191e+00],
#        [ 2.00422902e+00,  4.61460191e+00],
#        [ 1.18460093e+00,  3.42798147e+00],
#        [ 1.40693527e+00,  4.21297653e+00],
#        [ 1.80531863e+00,  3.03852655e+00],
#        [ 7.94681369e-01,  3.03852655e+00],
#        [ 2.37225890e+00,  1.85190611e+00],
#        [ 2.19277306e-01,  2.63690117e+00],
#        [ 3.01486628e+00,  1.46245119e+00],
#        [-4.14866280e-01,  1.46245119e+00],
#        [ 3.56450242e+00,  2.69745518e-01],
#        [-9.72966214e-01,  1.05474058e+00],
#        [ 4.22908400e+00, -1.19709396e-01],
#        [-1.62908400e+00, -1.19709396e-01],
#        [ 4.75216039e+00, -1.30632984e+00],
#        [-2.16062418e+00, -5.21334776e-01],
#        [ 5.43863164e+00, -1.69578475e+00],
#        [-2.83863164e+00, -1.69578475e+00],
#        [ 5.94440391e+00, -2.88849043e+00],
#        [-3.35286770e+00, -2.10349537e+00],
# ...

# %%
x[0], y[0]
# Out:
# (0.7277631148240451, 1.5097608010738912)

# %%
# count = 0
UE_0 = np.full(All_Center.shape[0], False) 
for m in range(len(x)):
    count = 0
    for i in range(len(All_Center)):
        if(math.sqrt(math.pow((x[m]-All_Center[i][0]), 2)+ math.pow((y[m]-All_Center[i][1]), 2)) < 0.5735):
            UE_0[i] = True
            count += 1
    print(count)
    break
del count
#     print(math.sqrt(math.pow((x[0]-All_Center[i][0]), 2)+ math.pow((y[0]-All_Center[i][1]), 2)))
#     print(math.sqrt(math.pow((x[i]-RedCenter_x), 2) + math.pow((y[i]-RedCenter_y), 2)) * math.pow(10, 3))

# %%
a, b, c, d = [np.where(UE_0[:] == True) for i in range(4)]
del a, b, c, d

# %%
def find_available_satellite(x_value, y_value, second):
    Centers = copy.deepcopy(All_Center)
    Centers = Satellites_Centers_at_time(Centers, second)
    mask = np.full(All_Center.shape[0], False)
    distance = []
    for i in range(len(Centers)):
        d = math.sqrt(math.pow((x_value-Centers[i][0]), 2)+ math.pow((y_value-Centers[i][1]), 2))
        if(d < 0.5735):
            distance.append(d)
            mask[i] = True
    available_satellite_index = list(np.where(mask)[0])
    return distance, available_satellite_index

# %%
distance, available_satellite_index = find_available_satellite(x[0], y[0], 2)
# All_Center[mask]

# %%
print(distance)
print(available_satellite_index)
# Out:
# [0.507505798987131, 0.18174808240655138, 0.36868246402594607, 0.4484844240432218, 0.5513475342679296]
# [59, 84, 87, 109, 134]

# %%
available_satellite_index

# %%
All_Center[0]

# %%
x[0], y[0]

# %%
RedLine_x[0][129]

# %%
All_Center[0]

# %%
All_Center_100 = Satellites_Centers_at_time(All_Center, 100)
All_Center_100[0]

# %%
x, y

# %%
find_available_satellite(x[2], y[2], 0)

# %%
def access_shortest_satellite_at_time(second):
    UE_access_satellite = []
    for i in range(len(x)):
        distance, available_satellite_index = find_available_satellite(x[i], y[i], second)
        UE_access_satellite.append(available_satellite_index[distance.index(min(distance))])
#         print(available_satellite_index[distance.index(min(distance))])
#         break
    return UE_access_satellite

# access_shortest_satellite(0)
def access_shortest_satellite_during_time(duration):
    access_table = np.zeros((duration, len(x)))
    for i in range(duration):
#         print(access_shortest_satellite_at_time(i))
        access_table[i] = access_shortest_satellite_at_time(i)
    return access_table
        
access_shortest_satellite_during_time(100)

# %%
np.set_printoptions(threshold=np.inf)
def access_longest_service_time_satellite_at_time(second):
    UE_access_satellite = []
    UE_duration = []
    for i in range(len(x)):
        distance, available_satellite_index = find_available_satellite(x[i], y[i], second)
        service_time = []
        for s in available_satellite_index:
            count = 1
            while True:
                Temporary_Centers = Satellites_Centers_at_time(All_Center, second+count)
                d = math.sqrt(math.pow((x[i] - Temporary_Centers[s][0]), 2) + math.pow((y[i] - Temporary_Centers[s][1]), 2))
                if d < 0.5735:
                    count += 1
                else:
                    service_time.append(count)
                    break
#         print('UE_', str(i), sep='')
#         print(service_time)
#         print(max(service_time))
#         print(distance)
#         print(available_satellite_index[service_time.index(max(service_time))])
        UE_access_satellite.append(available_satellite_index[service_time.index(max(service_time))])
        UE_duration.append(max(service_time))
#         print('-----------------------------------------------------------------------')
#     print('UE_access_satellite:', UE_access_satellite)
#     print('UE_duration:', UE_duration)    
    return UE_access_satellite, UE_duration

# access_longest_service_time_satellite_at_time(0)

def access_longest_service_time_satellite_during_time(duration):
    access_table = np.zeros((duration, len(x)))
    for i in range(duration):
#         print(np.where(access_table[i, :]) == 0)
        if(np.where(access_table[i, :] == 0)[0].size != 0):
            UE_access_satellite, UE_duration = access_longest_service_time_satellite_at_time(i)
            for index in np.where(access_table[i, :] == 0)[0]:
                access_table[i:i+UE_duration[index], index] = UE_access_satellite[index]
    return access_table
            
access_longest_service_time_satellite_during_time(100)

# %%
def access_shortest_satellite_slow_model_during_time(duration):
    access_table = np.zeros((duration, len(x)))
    for i in range(duration):
        if(np.where(access_table[i, :] == 0)[0].size != 0):
            for index in np.where(access_table[i, :] == 0)[0]:
                distance, available_satellite_index = find_available_satellite(x[index], y[index], i)
                UE_access_shortest_satellite = available_satellite_index[distance.index(min(distance))]
                count = 1
                while True:
                    Temporary_Centers = Satellites_Centers_at_time(All_Center, i+count)
                    d = math.sqrt(math.pow((x[index] - Temporary_Centers[UE_access_shortest_satellite][0]), 2) + math.pow((y[index] - Temporary_Centers[UE_access_shortest_satellite][1]), 2))
                    if d < 0.5735:
                        count += 1
                    else:
                        service_time = count
                        break
                access_table[i:i+service_time, index] = UE_access_shortest_satellite
    return access_table
        
access_shortest_satellite_slow_model_during_time(100)

# %%
All_Center[0]

# %%
s = 2 # rain attenuation coefficient (2dB)
P_transmit = 15 # satellite transmit power (dBW)
P
def channel_model_between_UE_satellite(x_value, y_value, satelliteLocation):
